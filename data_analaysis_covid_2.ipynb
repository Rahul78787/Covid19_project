# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Covide19India.csv')
# Out:
# C:\Users\Rahul Ozil Shah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#         Unnamed: 0  Num Cases Date Announced Age Bracket Gender  \
# 0                0        1.0     30/01/2020          20      F
# 1                1        1.0     02/02/2020         NaN    NaN
# 2                2        1.0     03/02/2020         NaN    NaN
# 3                3        1.0     02/03/2020          45      M
# 4                4        1.0     02/03/2020          24      M
# ...            ...        ...            ...         ...    ...
# 499503       25491        3.0     08/01/2021         NaN    NaN
# 499504       25492        2.0     08/01/2021         NaN    NaN
# 499505       25493        1.0     08/01/2021         NaN    NaN
# 499506       25494       11.0     08/01/2021         NaN    NaN
# 499507       25495        2.0     08/01/2021         NaN    NaN
#
#                    Detected City    Detected District Detected State  \
# 0                       Thrissur             Thrissur         Kerala
# 1                      Alappuzha            Alappuzha         Kerala
# 2                      Kasaragod            Kasaragod         Kerala
# 3       East Delhi (Mayur Vihar)           East Delhi          Delhi
# 4                      Hyderabad            Hyderabad      Telangana
# ...                          ...                  ...            ...
# 499503                       NaN  Saraikela-Kharsawan      Jharkhand
# 499504                       NaN  Saraikela-Kharsawan      Jharkhand
# 499505                       NaN                  Leh         Ladakh
# 499506                       NaN                  Leh         Ladakh
# 499507                       NaN               Kargil         Ladakh
#
#        Current Status   Day  Month    year
# 0           Recovered  30.0    1.0  2020.0
# 1           Recovered   2.0    2.0  2020.0
# 2           Recovered   3.0    2.0  2020.0
# 3           Recovered   2.0    3.0  2020.0
# 4           Recovered   2.0    3.0  2020.0
# ...               ...   ...    ...     ...
# 499503   Hospitalized   8.0    1.0  2021.0
# 499504      Recovered   8.0    1.0  2021.0
# 499505   Hospitalized   8.0    1.0  2021.0
# 499506      Recovered   8.0    1.0  2021.0
# 499507      Recovered   8.0    1.0  2021.0
#
# [499508 rows x 12 columns]

# %%
data=df.iloc[:,1:]
data
# Out:
#         Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0             1.0     30/01/2020          20      F                  Thrissur
# 1             1.0     02/02/2020         NaN    NaN                 Alappuzha
# 2             1.0     03/02/2020         NaN    NaN                 Kasaragod
# 3             1.0     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4             1.0     02/03/2020          24      M                 Hyderabad
# ...           ...            ...         ...    ...                       ...
# 499503        3.0     08/01/2021         NaN    NaN                       NaN
# 499504        2.0     08/01/2021         NaN    NaN                       NaN
# 499505        1.0     08/01/2021         NaN    NaN                       NaN
# 499506       11.0     08/01/2021         NaN    NaN                       NaN
# 499507        2.0     08/01/2021         NaN    NaN                       NaN
#
#           Detected District Detected State Current Status   Day  Month    year
# 0                  Thrissur         Kerala      Recovered  30.0    1.0  2020.0
# 1                 Alappuzha         Kerala      Recovered   2.0    2.0  2020.0
# 2                 Kasaragod         Kerala      Recovered   3.0    2.0  2020.0
# 3                East Delhi          Delhi      Recovered   2.0    3.0  2020.0
# 4                 Hyderabad      Telangana      Recovered   2.0    3.0  2020.0
# ...                     ...            ...            ...   ...    ...     ...
# 499503  Saraikela-Kharsawan      Jharkhand   Hospitalized   8.0    1.0  2021.0
# 499504  Saraikela-Kharsawan      Jharkhand      Recovered   8.0    1.0  2021.0
# 499505                  Leh         Ladakh   Hospitalized   8.0    1.0  2021.0
# 499506                  Leh         Ladakh      Recovered   8.0    1.0  2021.0
# 499507               Kargil         Ladakh      Recovered   8.0    1.0  2021.0
#
# [499508 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499508 entries, 0 to 499507
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Num Cases          499489 non-null  float64
#  1   Date Announced     499501 non-null  object
#  2   Age Bracket        119014 non-null  object
#  3   Gender             123358 non-null  object
#  4   Detected City      16599 non-null   object
#  5   Detected District  484632 non-null  object
#  6   Detected State     499485 non-null  object
#  7   Current Status     499495 non-null  object
#  8   Day                499501 non-null  float64
#  9   Month              499501 non-null  float64
#  10  year               499501 non-null  float64
# dtypes: float64(4), object(7)
# memory usage: 41.9+ MB

# %%
data.isnull()
# Out:
#         Num Cases  Date Announced  Age Bracket  Gender  Detected City  \
# 0           False           False        False   False          False
# 1           False           False         True    True          False
# 2           False           False         True    True          False
# 3           False           False        False   False          False
# 4           False           False        False   False          False
# ...           ...             ...          ...     ...            ...
# 499503      False           False         True    True           True
# 499504      False           False         True    True           True
# 499505      False           False         True    True           True
# 499506      False           False         True    True           True
# 499507      False           False         True    True           True
#
#         Detected District  Detected State  Current Status    Day  Month   year
# 0                   False           False           False  False  False  False
# 1                   False           False           False  False  False  False
# 2                   False           False           False  False  False  False
# 3                   False           False           False  False  False  False
# 4                   False           False           False  False  False  False
# ...                   ...             ...             ...    ...    ...    ...
# 499503              False           False           False  False  False  False
# 499504              False           False           False  False  False  False
# 499505              False           False           False  False  False  False
# 499506              False           False           False  False  False  False
# 499507              False           False           False  False  False  False
#
# [499508 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# Num Cases                19
# Date Announced            7
# Age Bracket          380494
# Gender               376150
# Detected City        482909
# Detected District     14876
# Detected State           23
# Current Status           13
# Day                       7
# Month                     7
# year                      7
# dtype: int64

# %%
data.isnull().sum(axis=0)
# Out:
# Num Cases                19
# Date Announced            7
# Age Bracket          380494
# Gender               376150
# Detected City        482909
# Detected District     14876
# Detected State           23
# Current Status           13
# Day                       7
# Month                     7
# year                      7
# dtype: int64

# %%
data.isnull().sum(axis=0).sort_values()
# Out:
# Date Announced            7
# Day                       7
# Month                     7
# year                      7
# Current Status           13
# Num Cases                19
# Detected State           23
# Detected District     14876
# Gender               376150
# Age Bracket          380494
# Detected City        482909
# dtype: int64

# %%
data.isnull().sum(axis=0).sort_values(ascending=False)/len(data)*100
# Out:
# Detected City        96.676930
# Age Bracket          76.173755
# Gender               75.304099
# Detected District     2.978130
# Detected State        0.004605
# Num Cases             0.003804
# Current Status        0.002603
# year                  0.001401
# Month                 0.001401
# Day                   0.001401
# Date Announced        0.001401
# dtype: float64

# %%
round(data.isnull().sum(axis=0).sort_values(ascending=False)/len(data)*100,2)
# Out:
# Detected City        96.68
# Age Bracket          76.17
# Gender               75.30
# Detected District     2.98
# Detected State        0.00
# Num Cases             0.00
# Current Status        0.00
# year                  0.00
# Month                 0.00
# Day                   0.00
# Date Announced        0.00
# dtype: float64

# %%
data.isnull().sum(axis=1)
# Out:
# 0         0
# 1         2
# 2         2
# 3         0
# 4         0
#          ..
# 499503    3
# 499504    3
# 499505    3
# 499506    3
# 499507    3
# Length: 499508, dtype: int64

# %%
data.isnull().sum(axis=1).sort_values(ascending=False)
# Out:
# 288843    11
# 422316    11
# 422318    11
# 422317    11
# 242262    11
#           ..
# 84288      0
# 84289      0
# 84290      0
# 84291      0
# 0          0
# Length: 499508, dtype: int64

# %%
data
# Out:
#         Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0             1.0     30/01/2020          20      F                  Thrissur
# 1             1.0     02/02/2020         NaN    NaN                 Alappuzha
# 2             1.0     03/02/2020         NaN    NaN                 Kasaragod
# 3             1.0     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4             1.0     02/03/2020          24      M                 Hyderabad
# ...           ...            ...         ...    ...                       ...
# 499503        3.0     08/01/2021         NaN    NaN                       NaN
# 499504        2.0     08/01/2021         NaN    NaN                       NaN
# 499505        1.0     08/01/2021         NaN    NaN                       NaN
# 499506       11.0     08/01/2021         NaN    NaN                       NaN
# 499507        2.0     08/01/2021         NaN    NaN                       NaN
#
#           Detected District Detected State Current Status   Day  Month    year
# 0                  Thrissur         Kerala      Recovered  30.0    1.0  2020.0
# 1                 Alappuzha         Kerala      Recovered   2.0    2.0  2020.0
# 2                 Kasaragod         Kerala      Recovered   3.0    2.0  2020.0
# 3                East Delhi          Delhi      Recovered   2.0    3.0  2020.0
# 4                 Hyderabad      Telangana      Recovered   2.0    3.0  2020.0
# ...                     ...            ...            ...   ...    ...     ...
# 499503  Saraikela-Kharsawan      Jharkhand   Hospitalized   8.0    1.0  2021.0
# 499504  Saraikela-Kharsawan      Jharkhand      Recovered   8.0    1.0  2021.0
# 499505                  Leh         Ladakh   Hospitalized   8.0    1.0  2021.0
# 499506                  Leh         Ladakh      Recovered   8.0    1.0  2021.0
# 499507               Kargil         Ladakh      Recovered   8.0    1.0  2021.0
#
# [499508 rows x 11 columns]

# %%
data.groupby('Month')['Num Cases'].sum()
# Out:
# Month
# 1.0      323686.0
# 2.0           4.0
# 3.0        3267.0
# 4.0       51749.0
# 5.0      242853.0
# 6.0      663181.0
# 7.0     1878471.0
# 8.0     3761761.0
# 9.0     5088546.0
# 10.0    4116679.0
# 11.0    2695136.0
# 12.0    1828219.0
# Name: Num Cases, dtype: float64

# %%
data[data['Current Status']=='Hospitalized']
# Out:
#         Num Cases Date Announced Age Bracket Gender Detected City  \
# 18            1.0     04/03/2020          55    NaN      Gurugram
# 19            1.0     04/03/2020          55    NaN      Gurugram
# 21            1.0     04/03/2020         NaN      M          Agra
# 26            1.0     04/03/2020         NaN    NaN          Agra
# 27            1.0     04/03/2020         NaN    NaN           NaN
# ...           ...            ...         ...    ...           ...
# 499482      102.0     08/01/2021         NaN    NaN           NaN
# 499483        2.0     08/01/2021         NaN    NaN           NaN
# 499484        4.0     08/01/2021         NaN    NaN           NaN
# 499503        3.0     08/01/2021         NaN    NaN           NaN
# 499505        1.0     08/01/2021         NaN    NaN           NaN
#
#           Detected District Detected State Current Status  Day  Month    year
# 18                 Italians        Haryana   Hospitalized  4.0    3.0  2020.0
# 19                 Italians        Haryana   Hospitalized  4.0    3.0  2020.0
# 21                     Agra  Uttar Pradesh   Hospitalized  4.0    3.0  2020.0
# 26                     Agra  Uttar Pradesh   Hospitalized  4.0    3.0  2020.0
# 27                     Agra  Uttar Pradesh   Hospitalized  4.0    3.0  2020.0
# ...                     ...            ...            ...  ...    ...     ...
# 499482               Ranchi      Jharkhand   Hospitalized  8.0    1.0  2021.0
# 499483              Simdega      Jharkhand   Hospitalized  8.0    1.0  2021.0
# 499484       West Singhbhum      Jharkhand   Hospitalized  8.0    1.0  2021.0
# 499503  Saraikela-Kharsawan      Jharkhand   Hospitalized  8.0    1.0  2021.0
# 499505                  Leh         Ladakh   Hospitalized  8.0    1.0  2021.0
#
# [298929 rows x 11 columns]

# %%
M=data[data['Current Status']=='Hospitalized'].groupby('Month')['Num Cases'].sum()
M
# Out:
# Month
# 1.0      146216.0
# 3.0        2862.0
# 4.0       48856.0
# 5.0      155781.0
# 6.0      395143.0
# 7.0     1111263.0
# 8.0     1990886.0
# 9.0     2622324.0
# 10.0    1873130.0
# 11.0    1279860.0
# 12.0     823056.0
# Name: Num Cases, dtype: float64

# %%
M.plot.bar()
plt.show()

# %%
data
# Out:
#         Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0             1.0     30/01/2020          20      F                  Thrissur
# 1             1.0     02/02/2020         NaN    NaN                 Alappuzha
# 2             1.0     03/02/2020         NaN    NaN                 Kasaragod
# 3             1.0     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4             1.0     02/03/2020          24      M                 Hyderabad
# ...           ...            ...         ...    ...                       ...
# 499503        3.0     08/01/2021         NaN    NaN                       NaN
# 499504        2.0     08/01/2021         NaN    NaN                       NaN
# 499505        1.0     08/01/2021         NaN    NaN                       NaN
# 499506       11.0     08/01/2021         NaN    NaN                       NaN
# 499507        2.0     08/01/2021         NaN    NaN                       NaN
#
#           Detected District Detected State Current Status   Day  Month    year
# 0                  Thrissur         Kerala      Recovered  30.0    1.0  2020.0
# 1                 Alappuzha         Kerala      Recovered   2.0    2.0  2020.0
# 2                 Kasaragod         Kerala      Recovered   3.0    2.0  2020.0
# 3                East Delhi          Delhi      Recovered   2.0    3.0  2020.0
# 4                 Hyderabad      Telangana      Recovered   2.0    3.0  2020.0
# ...                     ...            ...            ...   ...    ...     ...
# 499503  Saraikela-Kharsawan      Jharkhand   Hospitalized   8.0    1.0  2021.0
# 499504  Saraikela-Kharsawan      Jharkhand      Recovered   8.0    1.0  2021.0
# 499505                  Leh         Ladakh   Hospitalized   8.0    1.0  2021.0
# 499506                  Leh         Ladakh      Recovered   8.0    1.0  2021.0
# 499507               Kargil         Ladakh      Recovered   8.0    1.0  2021.0
#
# [499508 rows x 11 columns]

# %%
data.groupby('Gender')['Num Cases'].sum()
# Out:
# Gender
# F             43029.0
# Femal e           1.0
# M             81951.0
# M                 1.0
# M,                1.0
# Non-Binary       18.0
# Name: Num Cases, dtype: float64

# %%
data.groupby('Age Bracket')['Num Cases'].sum()
# Out:
# Age Bracket
# 0.5     1.0
# 1.0     3.0
# 1.6     1.0
# 3.0     1.0
# 4.0     1.0
#        ...
# 98      1.0
# 98.0    2.0
# 99      2.0
# 99.0    2.0
# s       5.0
# Name: Num Cases, Length: 336, dtype: float64

# %%
data.groupby('Age Bracket')['Num Cases'].sum().sort_values(ascending=False)
# Out:
# Age Bracket
# 30.0        1923.0
# 30          1826.0
# 35          1742.0
# 40.0        1718.0
# 40          1672.0
#              ...
# 29.6           1.0
# 4.5            1.0
# 5 Months       1.0
# 5 months       1.0
# 0.5            1.0
# Name: Num Cases, Length: 336, dtype: float64

# %%
M=data.groupby('Age Bracket')['Num Cases'].sum().sort_values(ascending=False).head(10)
M
# Out:
# Age Bracket
# 30.0    1923.0
# 30      1826.0
# 35      1742.0
# 40.0    1718.0
# 40      1672.0
# 35.0    1640.0
# 45.0    1592.0
# 45      1589.0
# 25      1582.0
# 32.0    1550.0
# Name: Num Cases, dtype: float64

# %%
M.plot.bar(figsize=(15,5))
plt.show()

# %%
data
# Out:
#         Num Cases Date Announced Age Bracket Gender             Detected City  \
# 0             1.0     30/01/2020          20      F                  Thrissur
# 1             1.0     02/02/2020         NaN    NaN                 Alappuzha
# 2             1.0     03/02/2020         NaN    NaN                 Kasaragod
# 3             1.0     02/03/2020          45      M  East Delhi (Mayur Vihar)
# 4             1.0     02/03/2020          24      M                 Hyderabad
# ...           ...            ...         ...    ...                       ...
# 499503        3.0     08/01/2021         NaN    NaN                       NaN
# 499504        2.0     08/01/2021         NaN    NaN                       NaN
# 499505        1.0     08/01/2021         NaN    NaN                       NaN
# 499506       11.0     08/01/2021         NaN    NaN                       NaN
# 499507        2.0     08/01/2021         NaN    NaN                       NaN
#
#           Detected District Detected State Current Status   Day  Month    year
# 0                  Thrissur         Kerala      Recovered  30.0    1.0  2020.0
# 1                 Alappuzha         Kerala      Recovered   2.0    2.0  2020.0
# 2                 Kasaragod         Kerala      Recovered   3.0    2.0  2020.0
# 3                East Delhi          Delhi      Recovered   2.0    3.0  2020.0
# 4                 Hyderabad      Telangana      Recovered   2.0    3.0  2020.0
# ...                     ...            ...            ...   ...    ...     ...
# 499503  Saraikela-Kharsawan      Jharkhand   Hospitalized   8.0    1.0  2021.0
# 499504  Saraikela-Kharsawan      Jharkhand      Recovered   8.0    1.0  2021.0
# 499505                  Leh         Ladakh   Hospitalized   8.0    1.0  2021.0
# 499506                  Leh         Ladakh      Recovered   8.0    1.0  2021.0
# 499507               Kargil         Ladakh      Recovered   8.0    1.0  2021.0
#
# [499508 rows x 11 columns]

# %%
M=data[data['Current Status']=='Hospitalized'].groupby('Detected State')['Num Cases'].sum().sort_values(ascending=False)
M
# Out:
# Detected State
# Maharashtra                                 1966147.0
# Karnataka                                    926114.0
# Andhra Pradesh                               885133.0
# Tamil Nadu                                   826239.0
# Kerala                                       801356.0
# Delhi                                        631277.0
# Uttar Pradesh                                592692.0
# West Bengal                                  559397.0
# Odisha                                       331455.0
# Rajasthan                                    313561.0
# Telangana                                    289989.0
# Chhattisgarh                                 287576.0
# Haryana                                      264668.0
# Bihar                                        256020.0
# Gujarat                                      252331.0
# Madhya Pradesh                               248839.0
# Assam                                        216566.0
# Punjab                                       168726.0
# Jammu and Kashmir                            122650.0
# Jharkhand                                    116477.0
# Uttarakhand                                   93153.0
# Himachal Pradesh                              56317.0
# Goa                                           51716.0
# Puducherry                                    38396.0
# Tripura                                       33298.0
# Manipur                                       28579.0
# Chandigarh                                    20227.0
# Arunachal Pradesh                             16765.0
# Meghalaya                                     13571.0
# Nagaland                                      11964.0
# Ladakh                                         9619.0
# Sikkim                                         5979.0
# Andaman and Nicobar Islands                    4952.0
# Mizoram                                        4260.0
# Dadra and Nagar Haveli and Daman and Diu       3366.0
# State Unassigned                                  0.0
# Name: Num Cases, dtype: float64

# %%
M.plot.bar(figsize=(15,5))
plt.show()

# %%
Day=data[data['Current Status']=='Hospitalized'].groupby(['Month','Day'])[['Num Cases']].sum()
Day
# Out:
#             Num Cases
# Month Day
# 1.0   1.0     20159.0
#       2.0     18144.0
#       3.0     16678.0
#       4.0     16278.0
#       5.0     17909.0
# ...               ...
# 12.0  27.0    20333.0
#       28.0    16072.0
#       29.0    20542.0
#       30.0    21945.0
#       31.0    19026.0
#
# [309 rows x 1 columns]

# %%
Day.unstack(level=0).plot(kind='bar',subplots=True,figsize=(10,10))
plt.show()

# %%
data['Current Status'].unique()
# Out:
# array(['Recovered', 'Hospitalized', 'Deceased', 'Migrated',
#        'Migrated_Other', nan, 'Migrated_other'], dtype=object)

# %%
data[data['Current Status']=='Deceased']['Num Cases'].sum()
# Out:
# 150044.0

# %%
data[data['Current Status']=='Deceased'].groupby('Detected State')['Num Cases'].sum().sort_values(ascending=False)
# Out:
# Detected State
# Maharashtra                                 49650.0
# Tamil Nadu                                  12186.0
# Karnataka                                   12137.0
# Delhi                                       10602.0
# West Bengal                                  9888.0
# Uttar Pradesh                                8441.0
# Andhra Pradesh                               7096.0
# Punjab                                       5423.0
# Gujarat                                      4192.0
# Madhya Pradesh                               3592.0
# Chhattisgarh                                 3469.0
# Kerala                                       3260.0
# Haryana                                      2940.0
# Rajasthan                                    2688.0
# Odisha                                       1944.0
# Jammu and Kashmir                            1903.0
# Uttarakhand                                  1562.0
# Telangana                                    1538.0
# Bihar                                        1428.0
# Assam                                        1058.0
# Jharkhand                                    1040.0
# Himachal Pradesh                              943.0
# Goa                                           744.0
# Puducherry                                    636.0
# Tripura                                       385.0
# Manipur                                       364.0
# Chandigarh                                    326.0
# Meghalaya                                     142.0
# Sikkim                                        129.0
# Ladakh                                        127.0
# Nagaland                                       83.0
# Andaman and Nicobar Islands                    62.0
# Arunachal Pradesh                              56.0
# Mizoram                                         8.0
# Dadra and Nagar Haveli and Daman and Diu        2.0
# Name: Num Cases, dtype: float64
